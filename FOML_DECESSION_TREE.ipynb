# %% [markdown]
# <a href="https://colab.research.google.com/github/NeyagapulaSiddhartha/NeyagapulaSiddhartha/blob/main/FOML_DECESSION_TREE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
# prompt: import a csv file

import pandas as pd
df = pd.read_csv('/content/sample_data/winequality-white.csv',sep=';')
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df['quality'] = df['quality'].apply(lambda x: 1 if x >= 7 else 0)

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        0
# 1      9.5        0
# 2     10.1        0
# ...

# %%
from logging import root
class Node:
    def __init__(self, feature=None, threshold=None, left=None, right=None, value=None):
        self.feature = feature
        self.df=df
        self.threshold = threshold
        self.left = null
        self.right = null
        self.value = value
        self.List =List
def update_data(root):
  return root
out="Quality"
def info_gain(i,df):
  df_Nm =df
  MEAN1=df[df[out]==0].mean()
  MEAN2=df[df[out]==1].mean()
  threshold=(MEAN1+MEAN2)/2
  df_Nm1=df[df[i]>threshold]
  df_Nm2=df[df[i]<=threshold]
  df_Nm11=df_Nm1[df_Nm1[out]==0]
  df_Nm12=df_Nm1[df_Nm1[out]==1]
  df_Nm21=df_Nm2[df_Nm2[out]==0]
  df_Nm22=df_Nm2[df_Nm2[out]==1]


  p1m1=len(df_Nm11)/len(df_Nm1)*log(len(df_Nm11)/len(df_Nm1))
  p2m1=len(df_Nm12)/len(df_Nm1)*log(len(df_Nm12)/len(df_Nm1))
  P2m2= len(df_Nm22)/len(df_Nm1)*log(len(df_Nm22)/len(df_Nm2))
  P1m2= len(df_Nm21)/len(df_Nm1)*log(len(df_Nm21)/len(df_Nm2))

  Im=(len(df_Nm1)/len(df_Nm))*(p1m1+p2m1 )+ (len(df_Nm2)/len(df_Nm))*(P2m2 + P1m2)
  return i,Im
def pure():

  return True


def DecessionTreeClassifier(Root , df):
  if(Root.List == []):
    return
  elif(pure(df))
    return
  else:
    max_info_gain=-1;
    for i in Root.List:
      info , index=info_gain(i,Root.df)
      max_info_gain=max(max_info_gain,info)
      threshold=index
      left =right =Root
      update_data(left)
      update_data(right)
      left.list=right.list=Root.List.rempove(index)
      Root.left=left
      Root.Right=right

    DecessionTreeClassifier(Root.left,df)
    DecessionTreeClassifier(Root.right,df)
# Out:
# 13      6.6
# 15      6.6
# 17      6.2
# 20      6.2
# 21      6.4
#        ...
# 4870    6.1
# 4876    6.2
# 4886    6.2
# 4887    6.2
# 4896    5.5
# Name: fixed acidity, Length: 1060, dtype: float64

# %%
df[df["quality"]==1]["fixed acidity"]
# Out:
# 13      6.6
# 15      6.6
# 17      6.2
# 20      6.2
# 21      6.4
#        ...
# 4870    6.1
# 4876    6.2
# 4886    6.2
# 4887    6.2
# 4896    5.5
# Name: fixed acidity, Length: 1060, dtype: float64
